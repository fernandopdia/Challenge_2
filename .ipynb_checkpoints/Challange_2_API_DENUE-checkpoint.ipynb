# %% [markdown]
# # Ciencia de Datos

# %% [markdown]
# ## Objetivo del reto

# %% [markdown]
# ### Actividad 1
#
# Utilizando la API de DENUE, extraer datos de su estado y visualizar el top 10 de Clases de actividades económicas
#
# Para hacer esto se necesita:
# 1. Obtener el token del inegi
# 2. Hacer la llamada a la api, haciendo una consulta al endpoint BuscarEntidad, con los datos necesarios (numero del estado, registro de inicio, registro final, token)
# 3. Transformar la respuesta de la API en un dataframe
# 4. Separar la columna ubicacion en 3 columnas (localidad, municipio, estado)
# 5. Hacer una grafica bar char sobre cuantos establecimientos hay por clase de actividad economica
#
# ### Actividad 2
#
# Seleccionar dos entidades y hacer comparativos sobre la clase de actividad economica
#
# 1. Obtener el token del inegi
# 2. Hacer la llamada a la api, haciendo una consulta al endpoint BuscarEntidad, con los datos necesarios (numero del estado, registro de inicio, registro final, token) para cada estado
# 3. Transformar las respuestas a dos dataframes
# 4. Unir los dataframes usando la funcion concat (https://pandas.pydata.org/docs/reference/api/pandas.concat.html)
# 5. Separar la columna ubicacion en 3 columnas (localidad, municipio, estado)
# 6. Hacer la comparacion sobre la clase de actividad economica entre los dos estados
#
# **Deadline Sunday 03th**
#
# *#HappyCoding*

# %% [markdown]
# <p style="color:#FF0000">Para poder extraer los datos de una API en este caso de INEGI, que cuenta con un sitio disponible para desarrolladores</p>
#
# <p style="color:#FF0000">a continuación se muestra el proceso de extracción de la API</p>
#
# <img src="img/a.png">
#
# hecho esto se necesita un TOKEN para proceder a desarrollar una aplicación
#
# <img src="img/correo.PNG">

# %% [markdown]
# <p style="color:#FF0000">api consultada</p>
#
# https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/6207024007,6207078924,6207095692,720504,5300000001,539260,710380,6207061840,702100,716013/es/0700/true/BISE/2.0/[key]?type=json
#
# <p style="color:#FF0000">key</p>
# <p style="color:#FF0000">23c81832-e1d2-3193-5505-1cc0bde56f69</p>
#
# https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/6207024007,6207078924,6207095692,720504,5300000001,539260,710380,6207061840,702100,716013/es/0700/true/BISE/2.0/23c81832-e1d2-3193-5505-1cc0bde56f69?type=json

# %%
import requests
import json
import pprint

# %%
url = "https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/6207024007,6207078924,6207095692,720504,5300000001,539260,710380,6207061840,702100,716013/es/0700/true/BISE/2.0/23c81832-e1d2-3193-5505-1cc0bde56f69?type=json"
params = {"INDICADOR":"539260"}

response = requests.get(url, params)

if response.status_code == 200:
    data = json.loads(response.text)
    pprint
    data = json.loads(response.text)
    pprint.pprint(data)
else:    
    print(f"Error: {response.status_code}")
# Out:
# {'Header': {'Email': 'atencion.usuarios@inegi.org.mx',
#             'Name': 'Datos compactos BISE'},
#  'Series': [{'FREQ': '3',
#              'INDICADOR': '539260',
#              'LASTUPDATE': '09/01/2023',
#              'NOTE': '',
#              'OBSERVATIONS': [{'COBER_GEO': '0700',
#                                'OBS_EXCEPTION': None,
#                                'OBS_NOTE': '',
#                                'OBS_SOURCE': '',
#                                'OBS_STATUS': '3',
#                                'OBS_VALUE': '103.74000000000000000000',
#                                'TIME_PERIOD': '2023'}],
#              'SOURCE': '21005',
#              'STATUS': '3',
#              'TOPIC': '141',
#              'UNIT': '116',
#              'UNIT_MULT': ''},
#             {'FREQ': '8',
#              'INDICADOR': '702100',
#              'LASTUPDATE': '25/08/2023',
#              'NOTE': '',
#              'OBSERVATIONS': [{'COBER_GEO': '0700',
# ...

# %% [markdown]
# <p style="color:#FF0000">Por medio de un INDICADOR se realiza una consulta para obtener el DICCIONARIO de los datos</p>
#
#
# <p style="color:#FF0000">Primero se prueba la api en el navegador</p>
# <img src="img/apijson.PNG">
#
# <p style="color:#FF0000">aquí se comprueba su funcionalidad</p>
#
# <img src="img/analizando_api.PNG">
#
# <p style="color:#FF0000">con las cabeceras a la vista se elige una de ellas para generar un corrida de muestra donde se obtendrá el DICCIONARIO DE DATOS con VALORES asignados.</p>
#
# <p style="color:#FF0000">params = {"INDICADOR":"539260"}</p>
#
# <a src="api.json">Consulte la api</a>

# %% [markdown]
# <h1 style="color:#0000FF">PARTE 2</h1>
